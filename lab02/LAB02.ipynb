# %% [markdown]
# # Data Transformation

# %%
##Scaling (Min-Max normalization):

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
datasets=pd.read_csv("Exercise-CarData.csv",na_values="??")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-0ffc9c8620d6> in <module>
# ----> 1 datasets=pd.read_csv("Exercise-CarData.csv",na_values="??")
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Exercise-CarData.csv'

# %%
datasets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-39fecb511475> in <module>
# ----> 1 datasets
#
# NameError: name 'datasets' is not defined

# %%
# Step 3: Seprate Input and Output attributes
import math

##datasets.replace(to_replace="??",
           ##value=math.nan)

print(datasets)

X = datasets.iloc[:, 2:].values
# Only last column
Y = datasets.iloc[:, 1].values
##print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c4944c4f94c1> in <module>
#       5            ##value=math.nan)
#       6
# ----> 7 print(datasets)
#       8
#       9 X = datasets.iloc[:, 2:].values
#
# NameError: name 'datasets' is not defined

# %%
X##input variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a26c81730d11> in <module>
# ----> 1 X##input variable
#
# NameError: name 'X' is not defined

# %%
Y## output variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-29f30952d9a8> in <module>
# ----> 1 Y## output variable
#
# NameError: name 'Y' is not defined

# %%
## perform scalling on age km

# %%
x_new=datasets.iloc[:,2:4]
scaler=MinMaxScaler()
scaled_x=scaler.fit_transform(x_new)
print(scaled_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f7259ee02014> in <module>
# ----> 1 x_new=datasets.iloc[:,2:4]
#       2 scaler=MinMaxScaler()
#       3 scaled_x=scaler.fit_transform(x_new)
#       4 print(scaled_x)
#
# NameError: name 'datasets' is not defined

# %%
std=StandardScaler()

# %%
std_x=std.fit_transform(x_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-10801c3f1125> in <module>
# ----> 1 std_x=std.fit_transform(x_new)
#
# NameError: name 'x_new' is not defined

# %%
std_x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-33d4d35ecf91> in <module>
# ----> 1 std_x
#
# NameError: name 'std_x' is not defined

# %% [markdown]
# # Handling Categorical Data

# %%
X = datasets.iloc[:, 2:].values
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-6fc206c34bdf> in <module>
# ----> 1 X = datasets.iloc[:, 2:].values
#       2 print(X)
#
# NameError: name 'datasets' is not defined

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
le=LabelEncoder()

# %%
X[ :,2]=le.fit_transform(X[ :,2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7ca24782c061> in <module>
# ----> 1 X[ :,2]=le.fit_transform(X[ :,2])
#
# NameError: name 'X' is not defined

# %%
print(X)

# %%
dummy=pd.get_dummies(datasets["FuelType"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-d081f58b5a7a> in <module>
# ----> 1 dummy=pd.get_dummies(datasets["FuelType"])
#
# NameError: name 'datasets' is not defined

# %%
print("\nDummy\n")
print(dummy)
# Out:
# Dummy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b707398bc70d> in <module>
#       1 print("\nDummy\n")
# ----> 2 print(dummy)
#
# NameError: name 'dummy' is not defined

# %%
new_dataset=datasets.drop(['FuelType','HP',	'MetColor',	'Automatic',	'CC',	'Doors',	'Weight'],axis=1)

# %%
new_dataset=pd.concat([dummy,new_dataset],axis=1)

# %%
new_dataset.drop(["Unnamed: 0"],inplace=True,axis=1)

# %%
new_dataset

# %% [markdown]
# # Handling the missing value

# %%
from sklearn.impute import SimpleImputer

# %%
print(datasets)

X = datasets.iloc[:, 2:].values
# Only last column
Y = datasets.iloc[:, 1].values
##print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a7037a65b80b> in <module>
# ----> 1 print(datasets)
#       2
#       3 X = datasets.iloc[:, 2:].values
#       4 # Only last column
#       5 Y = datasets.iloc[:, 1].values
#
# NameError: name 'datasets' is not defined

# %%
print("\n\nInput : \n", X)
print("\n\nOutput: \n", Y)

# %%
datasets.info()

# %%
updated_df=datasets

# %%
updated_df["Age"]=updated_df["Age"].fillna(updated_df["Age"].mean())

# %%
updated_df.info()

# %%
updated_df

# %%
updated_df["KM"]=updated_df["KM"].fillna(updated_df["KM"].mean())

# %%
updated_df.info()

# %% [markdown]
# #Using SimpleImputer from Scikit-Learn Library

# %%
X = datasets.iloc[:, 2:].values
# Only last column
Y = datasets.iloc[:, 1].values
##print(X)

# %%
print("\n\nInput : \n", X)
print("\n\nOutput: \n", Y)

# %%
datasets.info()

# %%
datasets.dropna(axis=0,how="all",inplace=True)##drop the row which have all the value as nan

# %%
datasets.info()

# %%
datasets.dropna(axis=0,how="any",inplace=True)##drop the row which have any the value as nan

# %%
datasets.info()

# %%
datasets

# %%
datasets.replace(to_replace="three",value=3)

# %%
datasets=pd.read_csv("Exercise-CarData.csv",na_values="??")

# %%
datasets.replace(to_replace="three",value=3)

# %%
imputer=SimpleImputer()

# %%
new_X = datasets.iloc[:, 2:4].values
# Only last column
new_Y = datasets.iloc[:, 1].values

# %%
new_X=np.array(new_X)

# %%
new_X

# %%
imputer=imputer.fit(new_X)

# %%
new_X=imputer.transform(new_X)

# %%
new_X.astype(int)

# %%
data=datasets.iloc[:,1:4]
import seaborn as sns

# %% [markdown]
# # Correlation

# %%
corr=data.corr()
corr.head()

# %%
sns.heatmap(corr)

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
  for j in range(i+1, corr.shape[0]):
    if corr.iloc[i,j] >= 0.9:
      if columns[j]:
        columns[j] = False

# %%
selected_columns = data.columns[columns]
selected_columns.shape

# %%
data = data[selected_columns]
print(data)
